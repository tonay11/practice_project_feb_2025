# %%
import os

f = open('beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt')
print(f.read())
# Out:
# Once upon a time there were four little Rabbits, and their names
# were--
#
#           Flopsy,
#        Mopsy,
#    Cotton-tail,
# and Peter.
#
# They lived with their Mother in a sand-bank, underneath the root of a
# very big fir-tree.
#
# 'Now my dears,' said old Mrs. Rabbit one morning, 'you may go into
# the fields or down the lane, but don't go into Mr. McGregor's garden:
# your Father had an accident there; he was put in a pie by Mrs.
# McGregor.'
#
# 'Now run along, and don't get into mischief. I am going out.'
#
# Then old Mrs. Rabbit took a basket and her umbrella, and went through
# the wood to the baker's. She bought a loaf of brown bread and five
# currant buns.
#
# Flopsy, Mopsy, and Cottontail, who were good little bunnies, went
# down the lane to gather blackberries:
#
# But Peter, who was very naughty, ran straight away to Mr. McGregor's
# garden, and squeezed under the gate!
#
# First he ate some lettuces and some French beans; and then he ate
# some radishes;
#
# ...

# %%
f = open('beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt')
lines = f.splitlines() 
print(lines) 
file_obj.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 f = open('beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt')
# ----> 2 lines = f.splitlines()
#       3 print(lines)
#       4 file_obj.close()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'splitlines'

# %%
txt = 'beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt'
x = txt.split(",",".")

print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 txt = 'beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt'
# ----> 2 x = txt.split(",",".")
#       4 print(x)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
file_obj = open("beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt", "r") 
  
# splitting the file data into lines 
lines = [[x.rstrip('\n')] for x in file_obj] 
print(lines) 
file_obj.close()
# Out:
# [['Once upon a time there were four little Rabbits, and their names'], ['were--'], [''], ['          Flopsy,'], ['       Mopsy,'], ['   Cotton-tail,'], ['and Peter.'], [''], ['They lived with their Mother in a sand-bank, underneath the root of a'], ['very big fir-tree.'], [''], ["'Now my dears,' said old Mrs. Rabbit one morning, 'you may go into"], ["the fields or down the lane, but don't go into Mr. McGregor's garden:"], ['your Father had an accident there; he was put in a pie by Mrs.'], ["McGregor.'"], [''], ["'Now run along, and don't get into mischief. I am going out.'"], [''], ['Then old Mrs. Rabbit took a basket and her umbrella, and went through'], ["the wood to the baker's. She bought a loaf of brown bread and five"], ['currant buns.'], [''], ['Flopsy, Mopsy, and Cottontail, who were good little bunnies, went'], ['down the lane to gather blackberries:'], [''], ["But Peter, who was very naughty, ran straight away to Mr. McGregor's"], ['garden, and squeezed under the gate!'], [
# ...

# %%
x = f.split(", ")

print(x)

str = f 

translator = str.maketrans('', '', string.punctuation)

# Remove punctuation
clean_text = s.translate(translator)
print(clean_text)

txt = open('beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt')
x = txt.split(",")

print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x = f.split(", ")
#       3 print(x)
#       5 str = f
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'split'

# %%
def generator_data(name): 
    # opening file 
    file = open(name, 'r') 
    while True: 
        line = file.readline() 
        if not line: 
            # closing file 
            file.close() 
            break
        # yield line 
        yield line 
  
  
data = generator_data("beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt") 
for line in data: 
    print(line.split())
# Out:
# ['Once', 'upon', 'a', 'time', 'there', 'were', 'four', 'little', 'Rabbits,', 'and', 'their', 'names']
# ['were--']
# []
# ['Flopsy,']
# ['Mopsy,']
# ['Cotton-tail,']
# ['and', 'Peter.']
# []
# ['They', 'lived', 'with', 'their', 'Mother', 'in', 'a', 'sand-bank,', 'underneath', 'the', 'root', 'of', 'a']
# ['very', 'big', 'fir-tree.']
# []
# ["'Now", 'my', "dears,'", 'said', 'old', 'Mrs.', 'Rabbit', 'one', 'morning,', "'you", 'may', 'go', 'into']
# ['the', 'fields', 'or', 'down', 'the', 'lane,', 'but', "don't", 'go', 'into', 'Mr.', "McGregor's", 'garden:']
# ['your', 'Father', 'had', 'an', 'accident', 'there;', 'he', 'was', 'put', 'in', 'a', 'pie', 'by', 'Mrs.']
# ["McGregor.'"]
# []
# ["'Now", 'run', 'along,', 'and', "don't", 'get', 'into', 'mischief.', 'I', 'am', 'going', "out.'"]
# []
# ['Then', 'old', 'Mrs.', 'Rabbit', 'took', 'a', 'basket', 'and', 'her', 'umbrella,', 'and', 'went', 'through']
# ...

# %%
with open("beatrix_potter_the_story_of_a_fierce_bad_rabbit.txt") as file:
    text = file.read().lower()

words = text.split()
word_counts = {}

for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

print (word_counts)

# getting max frequency
most_common = max(word_counts, key=word_counts.get)

# printing result
print("Word with maximum frequency : " + str(most_common))
# Out:
# {'once': 1, 'upon': 5, 'a': 28, 'time': 2, 'there': 2, 'were': 4, 'four': 2, 'little': 6, 'rabbits,': 1, 'and': 44, 'their': 2, 'names': 1, 'were--': 1, 'flopsy,': 3, 'mopsy,': 3, 'cotton-tail,': 1, 'peter.': 2, 'they': 1, 'lived': 1, 'with': 6, 'mother': 3, 'in': 14, 'sand-bank,': 1, 'underneath': 4, 'the': 45, 'root': 1, 'of': 14, 'very': 7, 'big': 3, 'fir-tree.': 2, "'now": 2, 'my': 1, "dears,'": 1, 'said': 1, 'old': 3, 'mrs.': 3, 'rabbit': 3, 'one': 2, 'morning,': 1, "'you": 1, 'may': 1, 'go': 3, 'into': 6, 'fields': 1, 'or': 2, 'down': 5, 'lane,': 1, 'but': 15, "don't": 2, 'mr.': 12, "mcgregor's": 2, 'garden:': 1, 'your': 1, 'father': 1, 'had': 11, 'an': 2, 'accident': 1, 'there;': 1, 'he': 35, 'was': 24, 'put': 3, 'pie': 1, 'by': 3, "mcgregor.'": 1, 'run': 2, 'along,': 1, 'get': 1, 'mischief.': 1, 'i': 3, 'am': 2, 'going': 2, "out.'": 1, 'then': 4, 'took': 1, 'basket': 1, 'her': 6, 'umbrella,': 1, 'went': 6, 'through': 1, 'wood': 2, 'to': 30, "baker's.": 1, 'she': 7, 'bought': 
# ...
