# %%
pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("main-language-spoken-borough-census.csv")
# Display the first few rows
print(df.head())
# Out:
#                                Unnamed: 0 Barking and Dagenham     Barnet  \
# 0                           Main Language            E09000002  E09000003
# 1     All usual residents aged 3 and over              174,667    340,431
# 2  English (English or Welsh if in Wales)              141,962    260,753
# 3         Welsh/Cymraeg (in England only)                    5         39
# 4                Other UK language: Total                   11         30
#
#       Bexley      Brent    Bromley     Camden City of London    Croydon  \
# 0  E09000004  E09000005  E09000006  E09000007      E09000001  E09000008
# 1    222,954    297,380    297,299    212,089          7,212    346,451
# 2    209,507    186,900    280,077    162,326          5,976    296,232
# 3         12         56         40         58              4         20
# 4          5         83         26         54              0         31
#
#       Ealing  ... East Midlands West Midlands       East     London  \
# ...

# %%
import pandas as pd

df = pd.read_csv('main-language-spoken-borough-census.csv')

# remove rows with empty cells
new_df = df.dropna()

print(new_df.to_string())

# Remove all rows with NULL values:
df.dropna(inplace = True)
df.drop('Wales', inplace=True, axis=1) 
print(df.to_string())
# Out:
#                                                                         Unnamed: 0 Barking and Dagenham     Barnet     Bexley      Brent    Bromley     Camden City of London    Croydon     Ealing    Enfield  Greenwich    Hackney Hammersmith and Fulham   Haringey     Harrow   Havering Hillingdon   Hounslow  Islington Kensington and Chelsea Kingston upon Thames    Lambeth   Lewisham     Merton     Newham  Redbridge Richmond upon Thames  Southwark     Sutton Tower Hamlets Waltham Forest Wandsworth Westminster North East North West Yorkshire and The Humber East Midlands West Midlands       East     London South East South West      Wales     England    Wales.1 England and Wales
# ...

# %%
#remove rows

# import pandas with shortcut 'pd' 
import pandas as pd   
  
# read_csv function which is used to read the required CSV file 
data = pd.read_csv('main-language-spoken-borough-census.csv') 
  
# display  
print("Original 'main-language-spoken-borough-census.csv' CSV Data: \n") 
print(data) 
  
# drop function which is used in removing or deleting rows or columns from the CSV files 
data.drop('Wales, inplace=True, axis=1) 
  
# display  
print("\nCSV Data after deleting the column 'year':\n") 
print(data)
# Out:
# Original 'main-language-spoken-borough-census.csv' CSV Data:
#
#                                         Unnamed: 0 Barking and Dagenham  \
# 0                                    Main Language            E09000002
# 1              All usual residents aged 3 and over              174,667
# 2           English (English or Welsh if in Wales)              141,962
# 3                  Welsh/Cymraeg (in England only)                    5
# 4                         Other UK language: Total                   11
# ..                                             ...                  ...
# 83  African Language: African language (all other)                  235
# 84            Other Languages: All other languages                  168
# 85            Sign Language: British sign language                   87
# 86        Sign Language: Sign Language (all other)                    8
# 87    Sign Language: Any Sign Communication System                    9
#
# ...
